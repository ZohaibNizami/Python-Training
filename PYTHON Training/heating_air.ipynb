# %%
import json

heating_air =[
    {
        "client_id": "AIANHE",
        "account_number": "803191179509",
        "date_listed": "2024-09-13",
        "service_date": "2024-05-13",
        "debtor": {
            "first_name": "demetrius",
            "last_name": "cox",
            "date_of_birth": "",
            "zip_code": "67063",
            "city_name": "hillsboro",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "412 east grand avenue",
            "phone_numbers": [
                "4076681565"
            ]
        },
        "responsible_person": {
            "first_name": "demetrius",
            "last_name": "cox",
            "date_of_birth": "",
            "zip_code": "67063",
            "city_name": "hillsboro",
            "state_name": "ks",
            "address_line_1": "412 east grand avenue",
            "phone_numbers": [
                "4076681565"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"res dignostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance": "90.00",
        "current_account_balance":"85.00",
        "amount_paid_to_date": "4.50",
        "payments": [
            {
                "payment_amount": "4.50",
                "transaction_amount":"4.50" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "8031911795752",
        "date_listed": "2024-09-13",
        "service_date": "2024-05-13",
        "debtor": {
            "first_name": "demetrius",
            "last_name": "cox",
            "date_of_birth": "",
            "zip_code": "67063",
            "city_name": "hillsboro",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "412 east grand avenue",
            "phone_numbers": [
                "4076681565"
            ]
        },
        "responsible_person": {
            "first_name": "demetrius",
            "last_name": "cox",
            "date_of_birth": "",
            "zip_code": "67063",
            "city_name": "hillsboro",
            "state_name": "ks",
            "address_line_1": "412 east grand avenue",
            "phone_numbers": [
                "4076681565"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"Generic contactor * 2 pole 25-30 amp 24v",
        "provider_location_name":"el dorado",
        "initial_account_balance": "286..48",
        "current_account_balance":"257.83",
        "amount_paid_to_date": "28.65",
        "payments": [
            {
                "payment_amount": "28.65",
                "transaction_amount":"28.65" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "803191179566",
        "date_listed": "2024-09-13",
        "service_date": "2024-05-20",
        "debtor": {
            "first_name": "christy",
            "last_name": "crupper",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "620 marmaton",
            "phone_numbers": [
                "3168285363"
            ]
        },
        "responsible_person": {
            "first_name": "christy",
            "last_name": "crupper",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "address_line_1": "620 marmaton",
            "phone_numbers": [
                "3168285363"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"res diagnostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance": "625.75",
        "current_account_balance":"625.75",
        "amount_paid_to_date":"" ,
        "payments": [
            {
                "payment_amount": "",
                "transaction_amount": "",
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "803191179611",
        "date_listed": "2024-09-13",
        "service_date": "2024-05-28",
        "debtor": {
            "first_name": "kim",
            "last_name": "roberts",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "315 weat cave springs avenue",
            "phone_numbers": [
                "3166412512"
            ]
        },
        "responsible_person": {
            "first_name": "kim",
            "last_name": "roberts",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "address_line_1": "315 weat cave springs avenue",
            "phone_numbers": [
                "3166412512"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"res diagnostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance":"215.00" ,
        "current_account_balance":"215.00",
        "amount_paid_to_date":"" ,
        "payments": [
            {
                "payment_amount":"" ,
                "transaction_amount":"" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "803191179452",
        "date_listed": "2024-09-13",
        "service_date": "2024-05-07",
        "debtor": {
            "first_name": "jarod",
            "last_name": "rutliff",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "1439 lawndale ave",
            "phone_numbers": [
                "3166170040"
            ]
        },
        "responsible_person": {
            "first_name": "jarod",
            "last_name": "rutiliff",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "address_line_1": "1439 lawndale ave",
            "phone_numbers": [
                "3166170040"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"diagnostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance":"394.36" ,
        "current_account_balance":"394.36",
        "amount_paid_to_date":"" ,
        "payments": [
            {
                "payment_amount":"" ,
                "transaction_amount":"" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "803191179334",
        "date_listed": "2024-09-13",
        "service_date": "2024-04-26",
        "debtor": {
            "first_name": "sandra",
            "last_name": "shields",
            "date_of_birth": "",
            "zip_code": "67010",
            "city_name": "augusta",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "4723 sw 100th st",
            "phone_numbers": [
                "3163234612"
            ]
        },
        "responsible_person": {
            "first_name": "sandra",
            "last_name": "shields",
            "date_of_birth": "",
            "zip_code": "67010",
            "city_name": "augusta",
            "state_name": "ks",
            "address_line_1": "4723 sw 100th st",
            "phone_numbers": [
                "3163234612"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"out of town diagnostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance":"110.00" ,
        "current_account_balance":"110.00",
        "amount_paid_to_date":"" ,
        "payments": [
            {
                "payment_amount":"" ,
                "transaction_amount":"" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "80319117547",
        "date_listed": "2024-09-13",
        "service_date": "2023-12-29",
        "debtor": {
            "first_name": "jared",
            "last_name": "storm",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "720 fredrick dr",
            "phone_numbers": [
                "3166171274"
            ]
        },
        "responsible_person": {
            "first_name": "jared",
            "last_name": "storm",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "address_line_1": "720 fredrick dr",
            "phone_numbers": [
                "3166171274"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"Rse diagnostic fees",
        "provider_location_name":"el dorado",
        "initial_account_balance":"242.50" ,
        "current_account_balance":"152.50",
        "amount_paid_to_date":"90.00" ,
        "payments": [
            {
                "payment_amount":"90.00" ,
                "transaction_amount":"90.00" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    },
    {
        "client_id": "AIANHE",
        "account_number": "80319117712",
        "date_listed": "2024-09-13",
        "service_date": "2023-01-17",
        "debtor": {
            "first_name": "derek",
            "last_name": "watts",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "854 fredrick dr",
            "phone_numbers": [
                "3163235164"
            ]
        },
        "responsible_person": {
            "first_name": "derek",
            "last_name": "watts",
            "date_of_birth": "",
            "zip_code": "67042",
            "city_name": "el dorado",
            "state_name": "ks",
            "address_line_1": "854 fredrick dr",
            "phone_numbers": [
                "3163235164"
            ]
        },
        "provider_name":"don's heating and air",
        "ar_debt_id":"",
        "procedure_code":"",
        "procedure_description":"repair",
        "provider_location_name":"el dorado",
        "initial_account_balance":"997.82" ,
        "current_account_balance":"498.91",
        "amount_paid_to_date":"498.91" ,
        "payments": [
            {
                "payment_amount":"498.91" ,
                "transaction_amount":"498.91" ,
                "payment_type": "prepayment",
                "transaction_type": "prepayment",
                "transaction_status": "paid",
                "payment_date": "2024-09-13"
            }
        ],
        "debt_notes": {        }
    }
    ]
with open('heating_air.json', 'w') as json_file:
    json.dump(heating_air, json_file, indent=4)
