# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK27174A1",
        "date_listed": "2024-04-30",
        "service_date": "2024-04-30",
        "debtor": {
            "first_name": "jessica",
            "last_name": "heck",
            "date_of_birth": "1982-02-16",
            "zip_code": "674227",
            "city_name": "bushton",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "po box 28",
            "phone_numbers": [
                "6203210224"
            ]
        },
        "responsible_person": {
            "first_name": "jessica",
            "last_name": "heck",
            "date_of_birth": "1982-02-16",
            "zip_code": "674227",
            "city_name": "bushton",
            "state_name": "ks",
            "address_line_1": "po box 28",
            "phone_numbers": [
                "6203210224"
            ]
        },
        "provider_name":"nathaniel knackstedt md",
        "ar_debt_id":"1265450480",
        "procedure_code":"99203",
        "procedure_description":"office o/p new low 30 min",
        "provider_location_name":"hays",
        "initial_account_balance": "925.00",
        "current_account_balance":"91.85",
        "amount_paid_to_date":"833.15" ,
        "payments": [
            {
                "payment_amount": "833.15",
                "transaction_amount":"833.15" ,
                "payment_type": "PRE PAYMENT",
                "transaction_type": "PRE PAYMENT",
                "transaction_status": "paid",
                "payment_date": "2024-04-30"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK11318A1",
        "date_listed": "2024-04-30",
        "service_date": "2024-04-19",
        "debtor": {
            "first_name": "steven",
            "last_name": "pihl",
            "date_of_birth": "1967-07-03",
            "zip_code": "67456",
            "city_name": "lindsborg",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "4696 w falun road",
            "phone_numbers": [
                "7858227754"
            ]
        },
        "responsible_person":
        {
            "first_name": "steven",
            "last_name": "pihl",
            "date_of_birth": "1967-07-03",
            "zip_code": "67456",
            "city_name": "lindsborg",
            "state_name": "ks",
            "address_line_1": "4696 w falun road",
            "phone_numbers": [
                "7858227754"
            ]
        },
        "provider_name":,"lori golbek aprn",
        "ar_debt_id":" 265450480",
        "procedure_code":"95912",
        "procedure_description":"nrv cndj test 11-12 studies",
        "provider_location_name":"salina",
        "initial_account_balance": "725.00",
        "current_account_balance":"405.00",
        "amount_paid_to_date": "320.00",
        "payments": [
            {
                "payment_amount":"320.00",
                "transaction_amount": "320.00",
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024-04-30"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK27364A1",
        "date_listed": "2024-04-30",
        "service_date": "2024-04-19",
        "debtor": {
            "first_name": "silvia",
            "last_name": "carrasco",
            "date_of_birth": "1981-01-03",
            "zip_code": "67530",
            "city_name": "great bend",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "4696 w falun road",
            "phone_numbers": [
                "6207971125"
            ]
        },
        "responsible_person":
        {
             "first_name": "silvia",
            "last_name": "carrasco",
            "date_of_birth": "1981-01-03",
            "zip_code": "67530",
            "city_name": "great bend",
            "state_name": "ks",
            "address_line_1": "4696 w falun road",
            "phone_numbers": [
                "6207971125"
            ]
        },
        "provider_name":"willam kossow,md",
        "ar_debt_id":"265450480",
        "procedure_code":"95912",
        "procedure_description":"nrv cndj test 11-12 studies",
        "provider_location_name":"salina",
        "initial_account_balance": "665.00",
        "current_account_balance":"345.00",
        "amount_paid_to_date": "320.00",
        "payments": [
            {
                "payment_amount": "320.00",
                "transaction_amount": "320.00",
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024-04-30"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK26645A1",
        "date_listed": "2024-05-06",
        "service_date": "2024-04-29",
        "debtor": {
            "first_name": "codi",
            "last_name": "feldkamp",
            "date_of_birth": "1984-07-10",
            "zip_code": "67418",
            "city_name": "barnard",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "427 victoria lane",
            "phone_numbers": [
                "7856508202"
            ]
        },
        "responsible_person": {
             "first_name": "codi",
            "last_name": "feldkamp",
            "date_of_birth": "1984-07-10",
            "zip_code": "67418",
            "city_name": "barnard",
            "state_name": "ks",
            "address_line_1": "427 victoria lane",
            "phone_numbers": [
                "7856508202"
            ]
        },
        "provider_name":"brady true np",
        "ar_debt_id":" 265450480",
        "procedure_code":"95911",
        "procedure_description":"nrv cndj test 9-10 studies",
        "provider_location_name":"salina",
        "initial_account_balance": "870.00",
        "current_account_balance":"505.60",
        "amount_paid_to_date": "364.40",
        "payments": [
            {
                "payment_amount":"364.40" ,
                "transaction_amount":"364.40" ,
                "payment_type": "pre payment",
                "transaction_type": "PRE PAYMENT",
                "transaction_status": "paid",
                "payment_date": "2024-05-06"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "4DDRWI",
        "account_number": "KCK22809A1",
        "date_listed": "2024-05-02",
        "service_date": "2024-04-02",
        "debtor": {
            "first_name": "karen",
            "last_name": "bell",
            "date_of_birth": "1940-10-01",
            "zip_code": "67669",
            "city_name": "stockton",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "305 s 6th st",
            "phone_numbers": [
                "9282289912"
            ]
        },
        "responsible_person": {
           "first_name": "karen",
            "last_name": "bell",
            "date_of_birth": "1940-10-01",
            "zip_code": "67669",
            "city_name": "stockton",
            "state_name": "ks",
            "address_line_1": "305 s 6th st",
            "phone_numbers": [
                "9282289912"
            ]
        },
        "provider_name":"jessica gaigoreva fnp",
        "ar_debt_id":" 265450480",
        "procedure_code":"95913",
        "procedure_description":"nrv cndj test 13/> studies",
        "provider_location_name":"hays",
        "initial_account_balance": "925.00",
        "current_account_balance":"75.00",
        "amount_paid_to_date": "850.00",
        "payments": [
            {
                "payment_amount":"850.00" ,
                "transaction_amount":"850.00" ,
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024-05-02"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK20038A1",
        "date_listed": "2024-05-06",
        "service_date": "2024-04-09",
        "debtor": {
            "first_name": "karl",
            "last_name": "ledin",
            "date_of_birth": "1960-08-13",
            "zip_code": "67501",
            "city_name": "hutchinnson",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "409 e campbell",
            "phone_numbers": [
                "6209319388"
            ]
        },
        "responsible_person": {
            "first_name": "karl",
            "last_name": "ledin",
            "date_of_birth": "1960-08-13",
            "zip_code": "67501",
            "city_name": "hutchinnson",
            "state_name": "ks",
            "address_line_1": "409 e campbell",
            "phone_numbers": [
                "6209319388"
            ]
        },
        "provider_name":"mark yackley md",
        "ar_debt_id":"265450480",
        "procedure_code":"95913",
        "procedure_description":"nrv cndj test 13/> studies",
        "provider_location_name":"salina",
        "initial_account_balance": "1165.00",
        "current_account_balance":"30.00",
        "amount_paid_to_date":"1135.00" ,
        "payments": [
            {
                "payment_amount": "1135.00",
                "transaction_amount": "1135.00",
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024-05-06"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK27296A1",
        "date_listed": "2024--4-22",
        "service_date": "2024-04-11",
        "debtor": {
            "first_name": "rosalba",
            "last_name": "tellez",
            "date_of_birth": "1992-08-23",
            "zip_code": "67501",
            "city_name": "hutchinson",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "216 west 10th street",
            "phone_numbers": [
                "6208993279"
            ]
        },
        "responsible_person": {
            "first_name": "rosalba",
            "last_name": "tellez",
            "date_of_birth": "1992-08-23",
            "zip_code": "67501",
            "city_name": "hutchinson",
            "state_name": "ks",
            "address_line_1": "216 west 10th street",
            "phone_numbers": [
                "6208993279"
            ]
        },
        "provider_name":"morgan deway pa",
        "ar_debt_id":" 265450480",
        "procedure_code":"95910",
        "procedure_description":"nrv cndj teswt 7-8 studies",
        "provider_location_name":"salina",
        "initial_account_balance": "655.00",
        "current_account_balance":"535.00",
        "amount_paid_to_date": "120.00",
        "payments": [
            {
                "payment_amount":  "120.00",
                "transaction_amount":  "120.00",
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024--4-22"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK27269A1",
        "date_listed": "2024-04-29",
        "service_date": "2024-04-03",
        "debtor": {
            "first_name": "megan",
            "last_name": "gwynn",
            "date_of_birth": "1993-05-03",
            "zip_code": "67554",
            "city_name": "lyons",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "431 e main",
            "phone_numbers": [
                "6205097081"
            ]
        },
        "responsible_person": {
            "first_name": "megan",
            "last_name": "gwynn",
            "date_of_birth": "1993-05-03",
            "zip_code": "67554",
            "city_name": "lyons",
            "state_name": "ks",
            "address_line_1": "431 e main",
            "phone_numbers": [
                "6205097081"
            ]
        },
        "provider_name":"deana wood aprn",
        "ar_debt_id":" 265450480",
        "procedure_code":"95913",
        "procedure_description":"nrv cndj test 13> studies",
        "provider_location_name":"great bend",
        "initial_account_balance":"975.00" ,
        "current_account_balance":"795.00",
        "amount_paid_to_date": "180.00",
        "payments": [
            {
                "payment_amount": "180.00",
                "transaction_amount":"180.00" ,
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2024-04-29"
            }
        ],
        "debt_notes": {        }
    }

# %%
{
        "client_id": "DDRWI",
        "account_number": "KCK26466A1",
        "date_listed": "2023-12-11",
        "service_date": "2023-11-27",
        "debtor": {
            "first_name": "charis",
            "last_name": "hauserman",
            "date_of_birth": "1969-03-03",
            "zip_code": "67432",
            "city_name": "clay center",
            "state_name": "ks",
            "ssn": "",
            "employer": "",
            "address_line_1": "1676 17th rd",
            "phone_numbers": [
                "7856324937"
            ]
        },
        "responsible_person": {
            "first_name": "charis",
            "last_name": "hauserman",
            "date_of_birth": "1969-03-03",
            "zip_code": "67432",
            "city_name": "clay center",
            "state_name": "ks",
            "address_line_1": "1676 17th rd",
            "phone_numbers": [
                "7856324937"
            ]
        },
        "provider_name":"david larson md",
        "ar_debt_id":"265450480",
        "procedure_code":"95911",
        "procedure_description":"nrv cndj test 9-10 studies",
        "provider_location_name":"salina",
        "initial_account_balance": "870.00",
        "current_account_balance":"665.00",
        "amount_paid_to_date": "205.00",
        "payments": [
            {
                "payment_amount":"205.00" ,
                "transaction_amount":"205.00" ,
                "payment_type": "pre payment",
                "transaction_type": "pre payment",
                "transaction_status": "paid",
                "payment_date": "2023-12-11"
            }
        ],
        "debt_notes": {        }
    }
